# %% [markdown]
# Site do Projeto: https://scrapy.org
#
#
# No Windows:
# pip install pypiwin32
# pip install scrapy
#
#
# Instalando Scapy através do código fonte:
# Efetue download do arquivo atual do scrapy e siga os passos (onde x.x.x é a versão que baixou):
# tar zxf scrapy-X.X.X.tar.gz
# cd scrapy-X.X.X
# python setup.py install

# %% [markdown]
# https://quotes.toscrape.com/
# lista citaçoes de famosos
#
# PRIMEIRO PROJETO
# - Criar um spider para rastrear e extrair dados desse site
# - "Spider" (o robô de coleta)
#
# No terminal:
# PS C:\Users\anacl\OneDrive\Área de Trabalho\cursos\web_scraping\4_Scrapy> scrapy startproject aulascrapy

# %%
import scrapy

# %%
class SpiderCitacoes(scrapy.Spider):
    name = 'citacoes'

    def start_requests(self):
        urls = [ "https://quotes.toscrape.com/page/1/", "https://quotes.toscrape.com/page/2/" ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
            # yield: retorno que nao sai do loop, envia a resposta


    # resultado: ['https:', '','quotes.toscrape.com', 'page', '1', '']
    def parse(self, response):
        pagina = response.url.split("/")[-2] # vai pegar o numero da pagina page/'1'
        nome_arquivo = f'citacoes-{pagina}.html'

        with open(nome_arquivo, 'wb') as f:
            f.write(response.body)

        self.log(f'Arquivo salvo {nome_arquivo}')

# %% [markdown]
# Executar o spider
# - scrapy crawl nome_do_spider
#
# Para executar, acesse a pasta de nivel superior do projeto onde esta o arquivo scrapy.cfg e execute
# - scrapy crawl citacoes
#
# Executara o spider denominado 'citacoes' definido em  'name = 'citacoes' '

# %% [markdown]
# para executar, criei o citacoes.py

# %% [markdown]
# #aulascrapy/ (raiz)
# #├── scrapy.cfg
# #└── aulascrapy/
# #    ├── spiders/
# #    │   ├── __init__.py
# #    │   └── citacoes.py  <-- ELE PRECISA ESTAR AQUI!
# #    ├── items.py
# #    └── settings.py

# %% [markdown]
# Se olhar agora na pasta aulascrapy (a pasta raiz onde está no terminal), verá dois novos arquivos: citacoes-1.html e citacoes-2.html. O Scrapy baixou o código HTML dessas páginas e salvou no computador, exatamente como programou no método parse
#
# Aqui está um resumo do que aconteceu nos logs:
#
# -Status 200: O Scrapy acessou com sucesso as duas páginas (/page/1/ e /page/2/).
#
# -Mensagem de Debug: Você pode ver [citacoes] DEBUG: Arquivo salvo citacoes-1.html, que é o resultado do seu self.log.
#
# -Finish Reason: O status final foi finished, indicando que ele processou tudo o que estava na lista de URLs.
